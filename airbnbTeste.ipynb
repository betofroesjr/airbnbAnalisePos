# %% [markdown]
# <a href="https://colab.research.google.com/github/betofroesjr/airbnbAnalisePos/blob/master/airbnbTeste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analise Airbnb

# %%
import pandas as pd
import io
import requests
import matplotlib.pyplot as plt
import numpy
import gzip
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
url = "http://data.insideairbnb.com/brazil/rj/rio-de-janeiro/2020-01-21/data/listings.csv.gz"
response = requests.get(url)
bytes_io = io.BytesIO(response.content)
with gzip.open(bytes_io, 'rt') as read_file:
    ds = pd.read_csv(read_file)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (61,62,94) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(ds.shape)
# Out:
# (34754, 106)

# %%
ds.head(5)
# Out:
#       id  ... reviews_per_month
# 0  17878  ...              2.12
# 1  21280  ...              1.23
# 2  25026  ...              2.02
# 3  31560  ...              2.39
# 4  35636  ...              2.29
#
# [5 rows x 106 columns]

# %%
ds = ds.drop(['id', 'listing_url','scrape_id', 'last_scraped', 'name','summary', 'space', 'description', 'neighborhood_overview', 'notes','transit','access','interaction','house_rules',
              'thumbnail_url','medium_url', 'picture_url','xl_picture_url','host_id','host_url','host_name', 'host_about','host_thumbnail_url','host_picture_url', 'host_verifications',
              'calendar_last_scraped','first_review','last_review','license','jurisdiction_names', 'cancellation_policy','zipcode'], axis=1)

# %%
print(ds.shape)
# Out:
# (34754, 74)

# %%
ds.head(5)
# Out:
#   experiences_offered  ... reviews_per_month
# 0                none  ...              2.12
# 1                none  ...              1.23
# 2                none  ...              2.02
# 3                none  ...              2.39
# 4                none  ...              2.29
#
# [5 rows x 74 columns]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34754 entries, 0 to 34753
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   experiences_offered                           34754 non-null  object
#  1   host_since                                    34749 non-null  object
#  2   host_location                                 34577 non-null  object
#  3   host_response_time                            22847 non-null  object
#  4   host_response_rate                            22847 non-null  object
#  5   host_acceptance_rate                          0 non-null      float64
#  6   host_is_superhost                             34749 non-null  object
#  7   host_neighbourhood                            22505 non-null  object
#  8   host_listings_count                           34749 non-null  float64
#  9   host_total_listings_count                     34749 non-null  float64
#  10  host_has_profile_pic                          34749 non-null  object
#  11  host_identity_verified                        34749 non-null  object
#  12  street                                        34754 non-null  object
#  13  neighbourhood                                 32972 non-null  object
#  14  neighbourhood_cleansed                        34754 non-null  object
#  15  neighbourhood_group_cleansed                  0 non-null      float64
#  16  city                                          34614 non-null  object
#  17  state                                         34712 non-null  object
#  18  market                                        34709 non-null  object
#  19  smart_location                                34754 non-null  object
#  20  country_code                                  34754 non-null  object
#  21  country                                       34754 non-null  object
#  22  latitude                                      34754 non-null  float64
#  23  longitude                                     34754 non-null  float64
#  24  is_location_exact                             34754 non-null  object
#  25  property_type                                 34754 non-null  object
#  26  room_type                                     34754 non-null  object
#  27  accommodates                                  34754 non-null  int64
#  28  bathrooms                                     34700 non-null  float64
#  29  bedrooms                                      34694 non-null  float64
#  30  beds                                          34579 non-null  float64
#  31  bed_type                                      34754 non-null  object
#  32  amenities                                     34754 non-null  object
#  33  square_feet                                   484 non-null    float64
#  34  price                                         34754 non-null  object
#  35  weekly_price                                  2445 non-null   object
#  36  monthly_price                                 2712 non-null   object
#  37  security_deposit                              19711 non-null  object
#  38  cleaning_fee                                  23840 non-null  object
#  39  guests_included                               34754 non-null  int64
#  40  extra_people                                  34754 non-null  object
#  41  minimum_nights                                34754 non-null  int64
#  42  maximum_nights                                34754 non-null  int64
#  43  minimum_minimum_nights                        34754 non-null  int64
#  44  maximum_minimum_nights                        34754 non-null  int64
#  45  minimum_maximum_nights                        34754 non-null  int64
#  46  maximum_maximum_nights                        34754 non-null  int64
#  47  minimum_nights_avg_ntm                        34754 non-null  float64
#  48  maximum_nights_avg_ntm                        34754 non-null  float64
#  49  calendar_updated                              34754 non-null  object
#  50  has_availability                              34754 non-null  object
#  51  availability_30                               34754 non-null  int64
#  52  availability_60                               34754 non-null  int64
#  53  availability_90                               34754 non-null  int64
#  54  availability_365                              34754 non-null  int64
#  55  number_of_reviews                             34754 non-null  int64
#  56  number_of_reviews_ltm                         34754 non-null  int64
#  57  review_scores_rating                          19462 non-null  float64
#  58  review_scores_accuracy                        19442 non-null  float64
#  59  review_scores_cleanliness                     19448 non-null  float64
#  60  review_scores_checkin                         19442 non-null  float64
#  61  review_scores_communication                   19450 non-null  float64
#  62  review_scores_location                        19445 non-null  float64
#  63  review_scores_value                           19447 non-null  float64
#  64  requires_license                              34754 non-null  object
#  65  instant_bookable                              34754 non-null  object
#  66  is_business_travel_ready                      34754 non-null  object
#  67  require_guest_profile_picture                 34754 non-null  object
#  68  require_guest_phone_verification              34754 non-null  object
#  69  calculated_host_listings_count                34754 non-null  int64
#  70  calculated_host_listings_count_entire_homes   34754 non-null  int64
#  71  calculated_host_listings_count_private_rooms  34754 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   34754 non-null  int64
#  73  reviews_per_month                             20348 non-null  float64
# dtypes: float64(20), int64(18), object(36)
# memory usage: 19.6+ MB

# %%
ds = ds.drop(['square_feet','weekly_price','monthly_price','host_acceptance_rate','neighbourhood_group_cleansed'], axis=1)

# %%
print(ds.shape)
# Out:
# (34754, 69)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34754 entries, 0 to 34753
# Data columns (total 69 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   experiences_offered                           34754 non-null  object
#  1   host_since                                    34749 non-null  object
#  2   host_location                                 34577 non-null  object
#  3   host_response_time                            22847 non-null  object
#  4   host_response_rate                            22847 non-null  object
#  5   host_is_superhost                             34749 non-null  object
#  6   host_neighbourhood                            22505 non-null  object
#  7   host_listings_count                           34749 non-null  float64
#  8   host_total_listings_count                     34749 non-null  float64
#  9   host_has_profile_pic                          34749 non-null  object
#  10  host_identity_verified                        34749 non-null  object
#  11  street                                        34754 non-null  object
#  12  neighbourhood                                 32972 non-null  object
#  13  neighbourhood_cleansed                        34754 non-null  object
#  14  city                                          34614 non-null  object
#  15  state                                         34712 non-null  object
#  16  market                                        34709 non-null  object
#  17  smart_location                                34754 non-null  object
#  18  country_code                                  34754 non-null  object
#  19  country                                       34754 non-null  object
#  20  latitude                                      34754 non-null  float64
#  21  longitude                                     34754 non-null  float64
#  22  is_location_exact                             34754 non-null  object
#  23  property_type                                 34754 non-null  object
#  24  room_type                                     34754 non-null  object
#  25  accommodates                                  34754 non-null  int64
#  26  bathrooms                                     34700 non-null  float64
#  27  bedrooms                                      34694 non-null  float64
#  28  beds                                          34579 non-null  float64
#  29  bed_type                                      34754 non-null  object
#  30  amenities                                     34754 non-null  object
#  31  price                                         34754 non-null  object
#  32  security_deposit                              19711 non-null  object
#  33  cleaning_fee                                  23840 non-null  object
#  34  guests_included                               34754 non-null  int64
#  35  extra_people                                  34754 non-null  object
#  36  minimum_nights                                34754 non-null  int64
#  37  maximum_nights                                34754 non-null  int64
#  38  minimum_minimum_nights                        34754 non-null  int64
#  39  maximum_minimum_nights                        34754 non-null  int64
#  40  minimum_maximum_nights                        34754 non-null  int64
#  41  maximum_maximum_nights                        34754 non-null  int64
#  42  minimum_nights_avg_ntm                        34754 non-null  float64
#  43  maximum_nights_avg_ntm                        34754 non-null  float64
#  44  calendar_updated                              34754 non-null  object
#  45  has_availability                              34754 non-null  object
#  46  availability_30                               34754 non-null  int64
#  47  availability_60                               34754 non-null  int64
#  48  availability_90                               34754 non-null  int64
#  49  availability_365                              34754 non-null  int64
#  50  number_of_reviews                             34754 non-null  int64
#  51  number_of_reviews_ltm                         34754 non-null  int64
#  52  review_scores_rating                          19462 non-null  float64
#  53  review_scores_accuracy                        19442 non-null  float64
#  54  review_scores_cleanliness                     19448 non-null  float64
#  55  review_scores_checkin                         19442 non-null  float64
#  56  review_scores_communication                   19450 non-null  float64
#  57  review_scores_location                        19445 non-null  float64
#  58  review_scores_value                           19447 non-null  float64
#  59  requires_license                              34754 non-null  object
#  60  instant_bookable                              34754 non-null  object
#  61  is_business_travel_ready                      34754 non-null  object
#  62  require_guest_profile_picture                 34754 non-null  object
#  63  require_guest_phone_verification              34754 non-null  object
#  64  calculated_host_listings_count                34754 non-null  int64
#  65  calculated_host_listings_count_entire_homes   34754 non-null  int64
#  66  calculated_host_listings_count_private_rooms  34754 non-null  int64
#  67  calculated_host_listings_count_shared_rooms   34754 non-null  int64
#  68  reviews_per_month                             20348 non-null  float64
# dtypes: float64(17), int64(18), object(34)
# memory usage: 18.3+ MB

# %%
ds.head(5)
# Out:
#   experiences_offered  ... reviews_per_month
# 0                none  ...              2.12
# 1                none  ...              1.23
# 2                none  ...              2.02
# 3                none  ...              2.39
# 4                none  ...              2.29
#
# [5 rows x 69 columns]

# %%
def remove_simbolo_monetario(x):
    a =  x[1:] #remove apenas um caracter
    result = ""
    for i in a:
        if i.isdigit() is True:
            result = result + i
    return result #retorna os digíto, sem o símbolo
    
ds["price"] = pd.to_numeric(ds["price"].apply(remove_simbolo_monetario), errors= "ignore")
ds["extra_people"] = pd.to_numeric(ds["extra_people"].apply(remove_simbolo_monetario), errors= "ignore")

# %%
ds["security_deposit"].fillna(0, inplace=True)
ds["price"].fillna(0, inplace=True)

# %%
ds["cleaning_fee"].fillna(0, inplace=True)
ds["host_neighbourhood"].fillna('', inplace=True)

# %%
ds['bed_type'] = ds.bed_type.astype('category')
ds['bed_type'].cat.categories
ds['bed_type'] = ds['bed_type'].cat.codes

# %%
ds['room_type'] = ds.room_type.astype('category')
ds['room_type'].cat.categories
ds['room_type'] = ds['room_type'].cat.codes

# %%
plt.figure(figsize = (7,7))
sns.set(style = "whitegrid")
f = sns.distplot(ds["price"])

# %%
q1 = ds["price"].quantile(0.25)
q3 = ds["price"].quantile(0.75)
IQR = q3 - q1
IF = q1 - (1.5 * IQR)
OF = q3 + (1.5 * IQR)

ds = ds[~((ds["price"] < IF) | (ds["price"] > OF))]
ds.shape
# Out:
# (31471, 69)

# %%
plt.figure(figsize=(27,27))
sns.heatmap(ds.corr(), annot=True)

# %%
list(set(ds.dtypes.tolist()))
# Out:
# [dtype('int8'), dtype('float64'), dtype('O'), dtype('int64')]

# %%
df_num = ds.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    host_listings_count  ...  reviews_per_month
# 0                  2.0  ...               2.12
# 1                  0.0  ...               1.23
# 2                  3.0  ...               2.02
# 3                  1.0  ...               2.39
# 4                  1.0  ...               2.29
#
# [5 rows x 37 columns]

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplot

# %%
df_num_corr = df_num.corr()['price'][:-1] # -1 because the latest row is price
golden_features_list = df_num_corr[abs(df_num_corr) > 0.38].sort_values(ascending=False)
print("There is {} strongly correlated values with SalePrice:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 3 strongly correlated values with SalePrice:
# price           1.000000
# bedrooms        0.436359
# accommodates    0.390812
# Name: price, dtype: float64

# %%
for i in range(0, len(df_num.columns), 5):
    sns.pairplot(data=df_num,
                x_vars=df_num.columns[i:i+5],
                y_vars=['price'])

# %%
plt.figure(figsize = (7,7))
sns.set(style = "whitegrid")
f = sns.distplot(ds["price"])

# %%
x = ds[['accommodates', 'bathrooms','bedrooms','beds', 'room_type']]
y = ds["price"]

# %%
x = x.fillna(method='ffill')
y = y.fillna(method='ffill')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics

x_train, x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
rf = RandomForestRegressor(n_estimators = 1500, verbose=1, criterion='mse')
rf.fit(x_train, y_train)

y_pred = rf.predict(x_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1500 out of 1500 | elapsed:    1.7s finished

# %%
modelo_regressaoLog = LogisticRegression(C = 0.7, random_state = 42)
modelo_regressaoLog.fit(x_train, y_train.ravel())

regressao_log_predict_test = modelo_regressaoLog.predict(x_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
print("Exatidão (Accuracy): {0:.4f}".format(metrics.accuracy_score(y_test, regressao_log_predict_test)))
print()
print("Classification Report")
print(metrics.classification_report(y_test, regressao_log_predict_test, labels = [1, 0]))
# Out:
# Exatidão (Accuracy): 0.0508
#
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            0       0.00      0.00      0.00         1
#
#    micro avg       0.00      0.00      0.00         1
#    macro avg       0.00      0.00      0.00         1
# weighted avg       0.00      0.00      0.00         1
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
